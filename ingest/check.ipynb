# %%
import pandas as pd

# %%
# import linkedin job posts from csv
df = pd.read_csv("../raw/linkedin/2026-02-06T035932.csv")
df.head()
# Out:
#           job_id job_website  \
# 0  li-4262353945    linkedin
# 1  li-4300405780    linkedin
# 2  li-4369104006    linkedin
# 3  li-4198762497    linkedin
# 4  li-4366384647    linkedin
#
#                                              job_url  \
# 0  https://www.linkedin.com/jobs-guest/jobs/api/j...
# 1  https://www.linkedin.com/jobs-guest/jobs/api/j...
# 2  https://www.linkedin.com/jobs-guest/jobs/api/j...
# 3  https://www.linkedin.com/jobs-guest/jobs/api/j...
# 4  https://www.linkedin.com/jobs-guest/jobs/api/j...
#
#                                        job_title  \
# 0  Business Intelligence (Shopee) Fresh Graduate
# 1    [TH] Business Intelligence - Fresh Graduate
# 2                                  Data Engineer
# 3                                  Data Engineer
# 4             Data Engineer (Digital Shelf Team)
#
#                          company_name  \
# 0                              Shopee
# 1                              Shopee
# 2                            OxygenAI
# 3  Locus Telecommunication Inc., Ltd.
# 4                                Cube
#
#                                          company_url    time_posted  \
# 0  https://sg.linkedin.com/company/shopee?trk=pub...     4 days ago
# 1  https://sg.linkedin.com/company/shopee?trk=pub...    2 weeks ago
# 2  https://th.linkedin.com/company/oxygenai?trk=p...    9 hours ago
# 3  https://th.linkedin.com/company/locus-telecomm...  10 months ago
# 4  https://sg.linkedin.com/company/cube-ecom?trk=...     1 week ago
#
#                      num_applicants                         location  \
# 0               Over 200 applicants  Bangkok, Bangkok City, Thailand
# 1               Over 200 applicants  Bangkok, Bangkok City, Thailand
# 2  Be among the first 25 applicants        Bangkok Metropolitan Area
# 3                    112 applicants  Bangkok, Bangkok City, Thailand
# 4  Be among the first 25 applicants  Bangkok, Bangkok City, Thailand
#
#     seniority_level employment_type  \
# 0  Mid-Senior level       Full-time
# 1       Entry level       Full-time
# 2       Entry level       Full-time
# 3       Entry level       Full-time
# 4  Mid-Senior level       Full-time
#
#                                  job_function  \
# 0  Strategy/Planning, Analyst, and Consulting
# 1  Strategy/Planning, Analyst, and Consulting
# 2                      Information Technology
# 3                      Information Technology
# 4                                       Other
#
#                                           industries  \
# 0  Internet Marketplace Platforms and Technology,...
# 1  Internet Marketplace Platforms and Technology,...
# 2                               Software Development
# 3                               Software Development
# 4                      IT Services and IT Consulting
#
#                                      job_description
# 0  <strong>Job Description</strong>\n<li>Developi...
# 1  <strong>About The Team</strong>\nThe \n<strong...
# 2  <strong>Responsibilities:</strong>\n<li>Design...
# 3  <strong>Job Description</strong>\n<li>Work on ...
# 4  We are seeking a mid-level Data Engineer to jo...

# %%
df.loc[2,'job_url']
# Out:
# 'https://www.linkedin.com/jobs-guest/jobs/api/jobPosting/4369104006'

# %%
len(df)
# Out:
# 2695

# %%
df["seniority_level"].value_counts()
# Out:
# seniority_level
# Entry level         969
# Not Applicable      762
# Mid-Senior level    669
# Associate           158
# Director             47
# Internship           38
# Executive             9
# Name: count, dtype: int64

# %%
for i in range(0, 100, 25):
    print(i)
# Out:
# 0
# 25
# 50
# 75

# %%
# save name timestamp 
from datetime import datetime
now = datetime.now()
timestamp = now.strftime("%Y-%m-%dT%H%M%S")
print("Current Timestamp :", timestamp)
# Out:
# Current Timestamp : 2026-02-06T035700
